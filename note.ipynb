# %%
import torch

# %%
data = torch.load('./processed_data/dual_graph_rev_res.pt')

# %%
data["train"]["ref"][0]
# Out:
# ['▁',
#  'head_info_entity',
#  '们到',
#  'jiao_info_entity',
#  '店',
#  '做',
#  '义',
#  '工',
#  ',',
#  '大家',
#  '要',
#  '帮',
#  'jiao_info_entity',
#  '店',
#  '把一',
#  'jiao_info_unit',
#  'jiao_info_unit',
#  'jiao_info_entity',
#  '搬到',
#  '仓库',
#  '里',
#  ',',
#  '一共有',
#  'eq_one_right_num_one',
#  '名',
#  'head_info_entity',
#  ',',
#  'x_entity',
#  '一人搬',
#  'eq_two_x_index',
#  'jiao_info_unit',
#  ',',
#  'y_entity',
#  '一人搬',
#  'eq_two_y_index',
#  'jiao_info_unit',
#  ',',
#  '共需要',
#  '搬',
#  'eq_two_right_num_one',
#  'jiao_info_unit',
#  ',',
#  '问',
#  'y_entity',
#  'x_entity',
#  '各有多少人',
#  '。']

# %%
data = torch.load('./score_exp_EMNLP/MaKE_res_seed_16.pt')

# %%
data
# Out:
# [['▁璇璇老师用350元买上衣和裤子共11件,每件上衣35元,每件裤子28元,陈老师两种书各买了多少件?</s>',
#   '▁陈老师到新华书店一共买了11件上衣和裤子,共用去350元.每件上衣35元,每件裤子28元,陈老师两种书各买了多少件?</s>',
#   '▁淘淘在商店买裤子和上衣共11件,每件裤子28元,每件上衣35元,共付款350元.请问买了______件裤子.</s>',
#   '▁淘淘在商店买裤子和上衣共11件,每件裤子28元,每件上衣35元,共付款350元.请问:淘淘分别买了多少件裤子和上衣?</s>',
#   '▁璇璇老师用350元买上衣和裤子共11件,每件上衣35元,每件裤子28元,那么老板卖出了多少件上衣?</s>'],
#  ['▁明明指动物,有一次他细心的发现好多狮子和四足的动物站在一起,有53只,明明蹲下来耐心的数出有132只腿,明明一下就算出了有多少只狮子多少只丹顶鹤,聪明的小朋友你能耐心的算出来吗?</s>',
#   '▁动物园里养了一些狮子和丹顶鹤共有53只,腿一共132条,那么狮子有多少只,丹顶鹤有多少只.</s>',
#   '▁动物园里有狮子和丹顶鹤共有53只,腿一共132条,那么狮子有多少只,丹顶鹤有多少只.</s>',
#   '▁小音画了狮子子,小九画了丹顶鹤,两种动物加起来一共有53只,数他们的腿有132只,不知道狮子子和丹顶鹤的分别有多少只呢?</s>',
#   '▁学校组织同学去动物园看动物,发现丹顶鹤和狮子有53只,腿有132条,则狮子有几只?</s>'],
#  ['▁鸡、狗共12只,共有腿36只.鸡鸡、狗各多少只.</s>',
#   '▁鸡、狗共12只,共有腿36只.鸡鸡、狗各多少只?</s>',
#   '▁鸡和狗共12只,数一数腿共36条,问鸡有多少只.</s>',
#   '▁鸡、狗共12只,共有腿36只.鸡多少只.</s>',
#   '▁鸡狗同笼,共12只,36条腿,鸡、狗各几只?</s>'],
#  ['▁为准确提供寺庙中46个大大象每天的需头量,统计到寺庙里大象每天喝4杯头,管理员每天喝6杯头,已知他们每天一共喝头128杯。请问大大象各有多少人?</s>',
# ...
